# %% [markdown]
# <center>CSE4022 Natural Language Processing</center>
# <center>Digital Assignment -2</center>
# 1.	Create a text corpus with minimum 200 words (unique contents). Implement the following text processing   <br>                                                                   <p>(10 Marks)</p> <br>
# <li>Word segmentation</li>
# <li>Sentence segmentation</li>
# <li>Convert to Lowercase</li>
# <li>Stop words removal</li>
# <li>Stemming</li>
# <li>Lemmatization</li>
# <li>Part of speech tagger</li>
#
#
#  Upload this in the same GitHub Account.

# %% [markdown]
# #### A TARAKESHWAR
# #### 19BCE1845
# #### DIGITAL ASSIGNMENT - 2

# %%
corpus = "The kids were loud. They were way too loud for Jerry, especially since this was a four-hour flight. The parents didn't seem to be able, or simply didn't want, to control them. They were yelling and fighting among themselves and it was impossible for any of the passengers to concentrate or rest. He thought about politely tapping on the parents' shoulders and asking them to try and get their kids under a bit more control, but before he did he came up with a better idea. Sure, it was a bit sinister, and he'd probably end p in a lot of trouble, but he really didn't care at that point.To the two friends, the treehouse was much more than a treehouse. It was a sanctuary away from the other kids where they could be themselves without being teased or bullied. It was their secret fortress hidden high in the branches of a huge oak that only they knew existed. At least that is what they thought. They were more than a little annoyed when their two younger sisters decided to turn the treehouse into a princess castle by painting the inside pink and putting glitter everywhere.It was easy to spot her. All you needed to do was look at her socks. They were never a matching pair. One would be green while the other would be blue. One would reach her knee while the other barely touched her ankle. Every other part of her was perfect, but never the socks. They were her micro act of rebellion."
corpus
# Out:
# "The kids were loud. They were way too loud for Jerry, especially since this was a four-hour flight. The parents didn't seem to be able, or simply didn't want, to control them. They were yelling and fighting among themselves and it was impossible for any of the passengers to concentrate or rest. He thought about politely tapping on the parents' shoulders and asking them to try and get their kids under a bit more control, but before he did he came up with a better idea. Sure, it was a bit sinister, and he'd probably end p in a lot of trouble, but he really didn't care at that point.To the two friends, the treehouse was much more than a treehouse. It was a sanctuary away from the other kids where they could be themselves without being teased or bullied. It was their secret fortress hidden high in the branches of a huge oak that only they knew existed. At least that is what they thought. They were more than a little annoyed when their two younger sisters decided to turn the treehouse in
# ...

# %% [markdown]
# ### Word segmentation

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize
words = word_tokenize(corpus)

# %%
words
# Out:
# ['The',
#  'kids',
#  'were',
#  'loud',
#  '.',
#  'They',
#  'were',
#  'way',
#  'too',
#  'loud',
#  'for',
#  'Jerry',
#  ',',
#  'especially',
#  'since',
#  'this',
#  'was',
#  'a',
#  'four-hour',
#  'flight',
#  '.',
#  'The',
#  'parents',
#  'did',
#  "n't",
#  'seem',
#  'to',
#  'be',
#  'able',
#  ',',
#  'or',
#  'simply',
#  'did',
#  "n't",
#  'want',
#  ',',
#  'to',
#  'control',
#  'them',
#  '.',
#  'They',
#  'were',
#  'yelling',
#  'and',
#  'fighting',
#  'among',
#  'themselves',
#  'and',
#  'it',
#  'was',
#  'impossible',
#  'for',
#  'any',
#  'of',
#  'the',
#  'passengers',
#  'to',
#  'concentrate',
#  'or',
#  'rest',
#  '.',
#  'He',
#  'thought',
#  'about',
#  'politely',
#  'tapping',
#  'on',
#  'the',
#  'parents',
#  "'",
#  'shoulders',
#  'and',
#  'asking',
#  'them',
#  'to',
#  'try',
#  'and',
#  'get',
#  'their',
#  'kids',
#  'under',
#  'a',
#  'bit',
#  'more',
#  'control',
#  ',',
#  'but',
#  'before',
#  'he',
#  'did',
# ...

# %% [markdown]
# ### Sentence segmentation

# %%
from nltk.tokenize import sent_tokenize
sentences=sent_tokenize(corpus)

# %%
sentences
# Out:
# ['The kids were loud.',
#  'They were way too loud for Jerry, especially since this was a four-hour flight.',
#  "The parents didn't seem to be able, or simply didn't want, to control them.",
#  'They were yelling and fighting among themselves and it was impossible for any of the passengers to concentrate or rest.',
#  "He thought about politely tapping on the parents' shoulders and asking them to try and get their kids under a bit more control, but before he did he came up with a better idea.",
#  "Sure, it was a bit sinister, and he'd probably end p in a lot of trouble, but he really didn't care at that point.To the two friends, the treehouse was much more than a treehouse.",
#  'It was a sanctuary away from the other kids where they could be themselves without being teased or bullied.',
#  'It was their secret fortress hidden high in the branches of a huge oak that only they knew existed.',
#  'At least that is what they thought.',
# ...

# %% [markdown]
# ### Convert to lowercase

# %%
lower = [i.lower() for i in words]

# %%
for i in range(len(lower)):
  print(words[i], '--->',lower[i])
# Out:
# The ---> the
# kids ---> kids
# were ---> were
# loud ---> loud
# . ---> .
# They ---> they
# were ---> were
# way ---> way
# too ---> too
# loud ---> loud
# for ---> for
# Jerry ---> jerry
# , ---> ,
# especially ---> especially
# since ---> since
# this ---> this
# was ---> was
# a ---> a
# four-hour ---> four-hour
# flight ---> flight
# . ---> .
# The ---> the
# parents ---> parents
# did ---> did
# n't ---> n't
# seem ---> seem
# to ---> to
# be ---> be
# able ---> able
# , ---> ,
# or ---> or
# simply ---> simply
# did ---> did
# n't ---> n't
# want ---> want
# , ---> ,
# to ---> to
# control ---> control
# them ---> them
# . ---> .
# They ---> they
# were ---> were
# yelling ---> yelling
# and ---> and
# fighting ---> fighting
# among ---> among
# themselves ---> themselves
# and ---> and
# it ---> it
# was ---> was
# impossible ---> impossible
# for ---> for
# any ---> any
# of ---> of
# the ---> the
# passengers ---> passengers
# to ---> to
# concentrate ---> concentrate
# ...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ### Stop words removal

# %%
from nltk.corpus import stopwords
stopword=stopwords.words('english')
filtered_words = [word for word in lower if word not in stopword]

# %%
filtered_words
# Out:
# ['kids',
#  'loud',
#  '.',
#  'way',
#  'loud',
#  'jerry',
#  ',',
#  'especially',
#  'since',
#  'four-hour',
#  'flight',
#  '.',
#  'parents',
#  "n't",
#  'seem',
#  'able',
#  ',',
#  'simply',
#  "n't",
#  'want',
#  ',',
#  'control',
#  '.',
#  'yelling',
#  'fighting',
#  'among',
#  'impossible',
#  'passengers',
#  'concentrate',
#  'rest',
#  '.',
#  'thought',
#  'politely',
#  'tapping',
#  'parents',
#  "'",
#  'shoulders',
#  'asking',
#  'try',
#  'get',
#  'kids',
#  'bit',
#  'control',
#  ',',
#  'came',
#  'better',
#  'idea',
#  '.',
#  'sure',
#  ',',
#  'bit',
#  'sinister',
#  ',',
#  "'d",
#  'probably',
#  'end',
#  'p',
#  'lot',
#  'trouble',
#  ',',
#  'really',
#  "n't",
#  'care',
#  'point.to',
#  'two',
#  'friends',
#  ',',
#  'treehouse',
#  'much',
#  'treehouse',
#  '.',
#  'sanctuary',
#  'away',
#  'kids',
#  'could',
#  'without',
#  'teased',
#  'bullied',
#  '.',
#  'secret',
#  'fortress',
#  'hidden',
#  'high',
#  'branches',
# ...

# %%
print("Number of tokens before stop word removal:",len(lower))
print("Number of tokens after stop word removal:",len(filtered_words))
# Out:
# Number of tokens before stop word removal: 287
# Number of tokens after stop word removal: 144

# %% [markdown]
# ### Stemmming

# %% [markdown]
# Here for stemming i used porter stemmer

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
stemmed_words=[]
for w in filtered_words:
    stemmed_words.append(ps.stem(w))

# %%
print("word","   ","stem\n")
for i in range(len(filtered_words)):
  print(filtered_words[i],'-->',stemmed_words[i])
# Out:
# word     stem
#
# kids --> kid
# loud --> loud
# . --> .
# way --> way
# loud --> loud
# jerry --> jerri
# , --> ,
# especially --> especi
# since --> sinc
# four-hour --> four-hour
# flight --> flight
# . --> .
# parents --> parent
# n't --> n't
# seem --> seem
# able --> abl
# , --> ,
# simply --> simpli
# n't --> n't
# want --> want
# , --> ,
# control --> control
# . --> .
# yelling --> yell
# fighting --> fight
# among --> among
# impossible --> imposs
# passengers --> passeng
# concentrate --> concentr
# rest --> rest
# . --> .
# thought --> thought
# politely --> polit
# tapping --> tap
# parents --> parent
# ' --> '
# shoulders --> shoulder
# asking --> ask
# try --> tri
# get --> get
# kids --> kid
# bit --> bit
# control --> control
# , --> ,
# came --> came
# better --> better
# idea --> idea
# . --> .
# sure --> sure
# , --> ,
# bit --> bit
# sinister --> sinist
# , --> ,
# 'd --> 'd
# probably --> probabl
# end --> end
# p --> p
# lot --> lot
# trouble --> troubl
# ...

# %% [markdown]
# ### Lemmatization

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk.stem import 	WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemma_words=[]
for w in filtered_words:
		lemma_words.append(lemmatizer.lemmatize(w))

# %%
print("word","   ","lemma\n")
for i in range(len(filtered_words)):
  print(filtered_words[i],'-->',lemma_words[i])
# Out:
# word     lemma
#
# kids --> kid
# loud --> loud
# . --> .
# way --> way
# loud --> loud
# jerry --> jerry
# , --> ,
# especially --> especially
# since --> since
# four-hour --> four-hour
# flight --> flight
# . --> .
# parents --> parent
# n't --> n't
# seem --> seem
# able --> able
# , --> ,
# simply --> simply
# n't --> n't
# want --> want
# , --> ,
# control --> control
# . --> .
# yelling --> yelling
# fighting --> fighting
# among --> among
# impossible --> impossible
# passengers --> passenger
# concentrate --> concentrate
# rest --> rest
# . --> .
# thought --> thought
# politely --> politely
# tapping --> tapping
# parents --> parent
# ' --> '
# shoulders --> shoulder
# asking --> asking
# try --> try
# get --> get
# kids --> kid
# bit --> bit
# control --> control
# , --> ,
# came --> came
# better --> better
# idea --> idea
# . --> .
# sure --> sure
# , --> ,
# bit --> bit
# sinister --> sinister
# , --> ,
# 'd --> 'd
# probably --> probably
# end --> end
# p --> p
# ...

# %% [markdown]
# #### Comparing lemmatization and stemming

# %%
print("word","   ","stem","   ","lemma\n")
for i in range(len(filtered_words)):
  print(filtered_words[i],'-->','stem: '+stemmed_words[i],'   ','lemma: '+lemma_words[i])
# Out:
# word     stem     lemma
#
# kids --> stem: kid     lemma: kid
# loud --> stem: loud     lemma: loud
# . --> stem: .     lemma: .
# way --> stem: way     lemma: way
# loud --> stem: loud     lemma: loud
# jerry --> stem: jerri     lemma: jerry
# , --> stem: ,     lemma: ,
# especially --> stem: especi     lemma: especially
# since --> stem: sinc     lemma: since
# four-hour --> stem: four-hour     lemma: four-hour
# flight --> stem: flight     lemma: flight
# . --> stem: .     lemma: .
# parents --> stem: parent     lemma: parent
# n't --> stem: n't     lemma: n't
# seem --> stem: seem     lemma: seem
# able --> stem: abl     lemma: able
# , --> stem: ,     lemma: ,
# simply --> stem: simpli     lemma: simply
# n't --> stem: n't     lemma: n't
# want --> stem: want     lemma: want
# , --> stem: ,     lemma: ,
# control --> stem: control     lemma: control
# . --> stem: .     lemma: .
# yelling --> stem: yell     lemma: yelling
# fighting --> stem: fight     lemma: fighting
# ...

# %% [markdown]
# ### Part of speech

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from nltk.tag import pos_tag
pos_tag(words)
# Out:
# [('The', 'DT'),
#  ('kids', 'NNS'),
#  ('were', 'VBD'),
#  ('loud', 'JJ'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('were', 'VBD'),
#  ('way', 'NN'),
#  ('too', 'RB'),
#  ('loud', 'JJ'),
#  ('for', 'IN'),
#  ('Jerry', 'NNP'),
#  (',', ','),
#  ('especially', 'RB'),
#  ('since', 'IN'),
#  ('this', 'DT'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('four-hour', 'JJ'),
#  ('flight', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('parents', 'NNS'),
#  ('did', 'VBD'),
#  ("n't", 'RB'),
#  ('seem', 'VB'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('able', 'JJ'),
#  (',', ','),
#  ('or', 'CC'),
#  ('simply', 'RB'),
#  ('did', 'VBD'),
#  ("n't", 'RB'),
#  ('want', 'VB'),
#  (',', ','),
#  ('to', 'TO'),
#  ('control', 'VB'),
#  ('them', 'PRP'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('were', 'VBD'),
#  ('yelling', 'VBG'),
#  ('and', 'CC'),
#  ('fighting', 'VBG'),
#  ('among', 'IN'),
#  ('themselves', 'PRP'),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('impossible', 'JJ'),
#  ('for', 'IN'),
# ...
